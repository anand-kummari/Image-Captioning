# %%
import matplotlib.pyplot as plt
import cv2
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
! python '/content/gdrive/My Drive/B.Tech Project/Image Captioning/CapGenerator/eval_model.py'
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-03-07 04:41:02.419657: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2019-03-07 04:41:02.420055: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1417c80 executing computations on platform Host. Devices:
# ...

# %%
# !ls /content/gdrive/My\ Drive/B.Tech\ Project/Image\ Captioning/models/
# Out:
# descriptions.txt			model_weight.h5
# features.pkl				README.md
# index_word.pkl				tokenizer.pkl
# model-ep001-loss4.604-val_loss3.939.h5	weights.h5
# model-ep002-loss3.656-val_loss3.746.h5	wholeModel.h5
# model-ep003-loss3.329-val_loss3.725.h5

# %%
# !python '/content/gdrive/My Drive/B.Tech Project/Image Captioning/CapGenerator/eval_model.py' -i '/content/gdrive/My Drive/B.Tech Project/Image Captioning/imgs/dog.jpg'
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-04-13 13:19:15.817511: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-13 13:19:15.817904: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x138fc80 executing computations on platform Host. Devices:
# ...

# %%
img = cv2.imread('/home/anand/Downloads/ski.jpg')
print(img.shape)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (486, 728, 3)

# %%
# !python '/content/gdrive/My Drive/B.Tech Project/Image Captioning/CapGenerator/eval_model.py' -i '/content/gdrive/My Drive/B.Tech Project/Image Captioning/imgs/ski.jpg'
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-04-13 13:12:21.740340: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-13 13:12:21.740824: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2787c80 executing computations on platform Host. Devices:
# ...

# %%
img = cv2.imread('/home/anand/Downloads/dog.jpg')
print(img.shape)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (512, 640, 3)

# %%
# !python '/content/gdrive/My Drive/B.Tech Project/Image Captioning/CapGenerator/eval_model.py' -i '/content/gdrive/My Drive/B.Tech Project/Image Captioning/imgs/dog.jpg'
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-04-13 14:42:06.923140: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-13 14:42:06.923486: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1d33c80 executing computations on platform Host. Devices:
# ...

# %%
# !python '/content/gdrive/My Drive/B.Tech Project/Image Captioning/CapGenerator/eval_model.py' -i '/content/gdrive/My Drive/B.Tech Project/Image Captioning/imgs/.jpg'
